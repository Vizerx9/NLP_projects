# %% [markdown]
# <a href="https://colab.research.google.com/github/Vizerx9/NLP_projects/blob/main/w2v_%D0%90%D0%B2%D1%81%D1%82%D1%80%D0%B8%D0%B9%D1%81%D0%BA%D0%B8%D0%B9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# В этом практикуме мы рассмотрим работу с библиотекой **Gensim** для работы с векторными представлениями текста
#
# Мы рассмотрим
# - **Word2Vec** - векторные представления слов
# - **FastText** - улучшенные представления с учетом морфологии
# - **Doc2Vec** - векторные представления документов

# %%
# !pip install gensim

import gensim
import gensim.downloader as api
from gensim.models import Word2Vec, FastText, Doc2Vec
from gensim.models.doc2vec import TaggedDocument
import numpy as np
# Out:
# Collecting gensim
#   Downloading gensim-4.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (8.4 kB)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.12/dist-packages (from gensim) (2.0.2)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from gensim) (1.16.3)
# Requirement already satisfied: smart_open>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from gensim) (7.6.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart_open>=1.8.1->gensim) (2.2.1)
# Downloading gensim-4.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (27.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 40.2 MB/s eta 0:00:00
# Installing collected packages: gensim
# Successfully installed gensim-4.4.0

# %% [markdown]
# ## Часть 1: Word2Vec
#
# ### Что такое Word2Vec?
#
# Word2Vec преобразует слова в векторы чисел так, что семантически похожие слова оказываются близко в векторном пространстве.
#
# **Два основных алгоритма:**
# - **CBOW** - предсказывает слово по контексту
# - **Skip-gram** - предсказывает контекст по слову
#
# **Загрузка предобученной модели**

# %%
w2v_model = api.load('glove-wiki-gigaword-100')

print(f"Размер словаря: {len(w2v_model.key_to_index)}")
print(f"Размерность векторов: {w2v_model.vector_size}")
# Out:
# [==================================================] 100.0% 128.1/128.1MB downloaded
# Размер словаря: 400000
# Размерность векторов: 100

# %%
print(list(api.info()['corpora'].keys())) # Список текстовых корпусов
print(list(api.info()['models'].keys()))  # Список предобученных моделей
# Out:
# ['semeval-2016-2017-task3-subtaskBC', 'semeval-2016-2017-task3-subtaskA-unannotated', 'patent-2017', 'quora-duplicate-questions', 'wiki-english-20171001', 'text8', 'fake-news', '20-newsgroups', '__testing_matrix-synopsis', '__testing_multipart-matrix-synopsis']
# ['fasttext-wiki-news-subwords-300', 'conceptnet-numberbatch-17-06-300', 'word2vec-ruscorpora-300', 'word2vec-google-news-300', 'glove-wiki-gigaword-50', 'glove-wiki-gigaword-100', 'glove-wiki-gigaword-200', 'glove-wiki-gigaword-300', 'glove-twitter-25', 'glove-twitter-50', 'glove-twitter-100', 'glove-twitter-200', '__testing_word2vec-matrix-synopsis']

# %% [markdown]
# Найдите документацию `gensim`: какие датасеты кроме `glove-wiki-gigaword-100` доступны в библиотеке?
#
# Выберите 3 датасета и кратко опишите их (источник данных, примерный объем, зачем такой датасет может использоваться)

# %% [markdown]
# Получается glove-wiki-gigaword-100 э

# %% [markdown]
# 1. word2vec-ruscorpora-300

# %%
w2v_model1 = api.load('word2vec-ruscorpora-300')
print(f"Размер словаря: {len(w2v_model1.key_to_index)}")
print(f"Размерность векторов: {w2v_model1.vector_size}")
# Out:
# [==================================================] 100.0% 198.8/198.8MB downloaded
# Размер словаря: 184973
# Размерность векторов: 300

# %% [markdown]
# Данный датасет используется для работы с русским языком что очевидно из названия. Судя по количеству слов и размерности вектора, с помощью него решают широкий круг задач (оцена семантической близости, анализ тональности текстов и т.п.

# %% [markdown]
# 2. glove-twitter-50
# Модель обучена на миллионах твитах и содержит более миллиона векторов для уникальных токинов. Скорее всего используется для уже перечисленных задач, если дело касается интернет-дискурса.

# %% [markdown]
# 3. text8
# Это небольшой хорошо предобработанный датасет для "незатратного" обучения собственных моеделей.

# %% [markdown]
# **Базовые операции с векторами**

# %%
# Получаем вектор слова
vector = w2v_model['computer']
print(f"Вектор слова 'computer': {vector[:5]}...")  # Показываем первые 5 чисел

# Вычисляем схожесть между словами
similarity = w2v_model.similarity('computer', 'laptop')
print(f"Схожесть 'computer' и 'laptop': {similarity:.4f}")
# Out:
# Вектор слова 'computer': [-0.16298   0.30141   0.57978   0.066548  0.45835 ]...
# Схожесть 'computer' и 'laptop': 0.7024

# %% [markdown]
# **Поиск похожих слов**

# %%
# Находим похожие слова
similar_words = w2v_model.most_similar('python', topn=5)
print("Слова, похожие на 'python':")
for word, score in similar_words:
    print(f"  {word}: {score:.4f}")

# %% [markdown]
# *Ваш ответ здесь*

# %% [markdown]
# **Задание**
#
# 1. Загрузите любой датасет из gensim на ваш выбор
#
# Модель word2vec-ruscorpora-300 загружена выше

# %%
w2v_model1 = api.load('word2vec-ruscorpora-300')

# %% [markdown]
# 2. Напишите функцию, которая принимает на вход любое слово и вовращает 10 наиболее близких по вектору слов

# %%
def similar_words(word, topn=10):
    print(f"\nПохожие слова для слова '{word}'")
    try:
        print("\nПохожие слова:")
        similarity = w2v_model1.most_similar(word, topn=topn)
        for similar_word, score in similarity:
            print(f"  {similar_word}: {score:.3f}")
    except KeyError:
        print(f"  Слово '{word}' не найдено в  модели")

similar_words('дом_NOUN')
# Out:
# Похожие слова для слова 'дом_NOUN'
#
# Похожие слова:
#   дома_ADV: 0.684
#   домик_NOUN: 0.672
#   особняк_NOUN: 0.668
#   квартира_NOUN: 0.636
#   флигель_NOUN: 0.633
#   двухэтажный_ADJ: 0.599
#   полукаменный_ADJ: 0.586
#   мезонин_NOUN: 0.574
#   усадьба_NOUN: 0.573
#   изба_NOUN: 0.571

# %% [markdown]
# 3. Обучите модель Word2Vec на тестовом датасете из ячейки ниже
#
# Примените следующие настройки:
#
# - размер вектора: 50
# - размер окна: 3
# - минимальная частота слова: 1
# - потоков: 2
# - использовать skip-gram

# %%
cooking_sentences = [
    ['варить', 'суп', 'овощи', 'морковь', 'картофель'],
    ['жарить', 'курица', 'сковорода', 'масло', 'специи'],
    ['печь', 'хлеб', 'мука', 'дрожжи', 'духовка'],
    ['резать', 'овощи', 'салат', 'помидоры', 'огурцы'],
    ['смешивать', 'ингредиенты', 'тесто', 'яйца', 'молоко'],
    ['варить', 'паста', 'вода', 'соль', 'соус'],
    ['гриль', 'мясо', 'овощи', 'уголь', 'барбекю'],
    ['тушить', 'говядина', 'горшок', 'вино', 'травы'],
    ['запекать', 'рыба', 'лимон', 'духовка', 'фольга'],
    ['готовить', 'завтрак', 'яичница', 'бекон', 'тост'],
    ['месить', 'тесто', 'пирог', 'начинка', 'яблоки'],
    ['кипятить', 'вода', 'чай', 'кофе', 'чашка'],
    ['мариновать', 'мясо', 'соус', 'специи', 'холодильник'],
    ['взбивать', 'сливки', 'сахар', 'десерт', 'торт'],
    ['парить', 'овощи', 'здоровое', 'питание', 'брокколи']
]

# %%
skipgram_model = Word2Vec(
    sentences=cooking_sentences,
    vector_size=50,
    window=3,
    min_count=1,
    workers=2,
    sg=1
)

# %%
print(f"Слова в словаре: {list(skipgram_model.wv.key_to_index.keys())[:10]}...")
# Out:
# Слова в словаре: ['овощи', 'мясо', 'соус', 'вода', 'тесто', 'духовка', 'специи', 'варить', 'брокколи', 'питание']...

# %% [markdown]
# 4. Проверьте модель

# %%
# Проверяем похожие слова в кулинарной тематике
try:
    similar = skipgram_model.wv.most_similar('варить', topn=5)
    print("Слова, похожие на 'варить':")
    for word, score in similar:
        print(f"  {word}: {score:.4f}")
except KeyError:
    print("Слово 'варить' не найдено в словаре")
# Out:
# Слова, похожие на 'варить':
#   вино: 0.2398
#   ингредиенты: 0.2172
#   хлеб: 0.1938
#   брокколи: 0.1846
#   кипятить: 0.1711

# %%
# Найдите слова, похожие на "духовка"
### ваш код здесь ###
try:
    similar = skipgram_model.wv.most_similar('духовка', topn=5)
    print("Слова, похожие на 'варить':")
    for word, score in similar:
        print(f"  {word}: {score:.4f}")
except KeyError:
    print("Слово 'варить' не найдено в словаре")

# Найдите слова, похожие на "овощи"
### ваш код здесь ###
try:
    similar = skipgram_model.wv.most_similar('овощи', topn=5)
    print("Слова, похожие на 'варить':")
    for word, score in similar:
        print(f"  {word}: {score:.4f}")
except KeyError:
    print("Слово 'варить' не найдено в словаре")
# Out:
# Слова, похожие на 'варить':
#   ингредиенты: 0.3199
#   десерт: 0.3064
#   холодильник: 0.2705
#   питание: 0.2243
#   пирог: 0.2142
# Слова, похожие на 'варить':
#   мариновать: 0.2716
#   хлеб: 0.2691
#   гриль: 0.2546
#   фольга: 0.2409
#   сахар: 0.2108

# %% [markdown]
# ## Часть 2: FastText

# %% [markdown]
# FastText улучшает Word2Vec, рассматривая слова как наборы символов (n-грамм). Это позволяет работать с редкими словами и опечатками

# %% [markdown]
# 5. Обучите FastText на корпусе текстов из пункта 3. Используйте код ниже

# %%
ft_model = FastText(
    sentences=cooking_sentences,
    vector_size=50,
    window=3,
    min_count=1,
    workers=2
)

# %% [markdown]
# 6. Найдите слова, похожие на "варить", "духовка" и "овощи" с помощью обученной модели. Используйте код из пункта 4

# %%
def similarity(word):
    try:
        similar = ft_model.wv.most_similar(word, topn=5)
        print(f"Слова, похожие на {word}:")
        for n, score in similar:
            print(f"  {n}: {score:.4f}")
    except KeyError:
        print(f"Слово {word} не найдено в словаре")
similarity('варить')
similarity('духовка')
similarity('овощи')
# Out:
# Слова, похожие на варить:
#   жарить: 0.5353
#   парить: 0.4805
#   месить: 0.3541
#   тушить: 0.3405
#   специи: 0.2622
# Слова, похожие на духовка:
#   взбивать: 0.4565
#   лимон: 0.3561
#   салат: 0.3050
#   курица: 0.3041
#   тост: 0.2944
# Слова, похожие на овощи:
#   жарить: 0.2960
#   фольга: 0.2574
#   морковь: 0.2297
#   соус: 0.2172
#   торт: 0.2094

# %% [markdown]
# 7. Сравните модели
#
# Дана функция для сравнения Word2Vec и FastText
#
# Придумайте 3 слова с опечатками и проверьте, найдет ли их FastText и Word2Vec

# %%
def compare_models(word):
    """Сравнивает представления слова в разных моделях"""
    print(f"\nСравнение для слова: '{word}'")

    # Word2Vec
    try:
        w2v_similar = skipgram_model.wv.most_similar(word, topn=2)
        print(f"  Word2Vec: {[w for w, _ in w2v_similar]}")
    except KeyError:
        print(f"  Word2Vec: слово не найдено")

    # FastText
    try:
        ft_similar = ft_model.wv.most_similar(word, topn=2)
        print(f"  FastText: {[w for w, _ in ft_similar]}")
    except KeyError:
        print(f"  FastText: слово не найдено")

# Сравниваем для разных слов
compare_models('столишница')
compare_models('дезерт')
compare_models('свикла')
# Out:
# Сравнение для слова: 'столишница'
#   Word2Vec: слово не найдено
#   FastText: ['яичница', 'десерт']
#
# Сравнение для слова: 'дезерт'
#   Word2Vec: слово не найдено
#   FastText: ['чай', 'мариновать']
#
# Сравнение для слова: 'свикла'
#   Word2Vec: слово не найдено
#   FastText: ['суп', 'мука']

# %% [markdown]
# ## Часть 3: Doc2Vec

# %% [markdown]
# Doc2Vec расширяет Word2Vec для создания векторных представлений целых документов (предложений, абзацев, статей)

# %%
# Создаем размеченные документы
documents = [
    "machine learning is interesting",
    "deep learning uses neural networks",
    "python programming for data science",
    "artificial intelligence is amazing",
    "computer vision processes images"
]

# Преобразуем в формат TaggedDocument
tagged_docs = []
for i, doc in enumerate(documents):
    tokens = doc.split()
    tagged_doc = TaggedDocument(words=tokens, tags=[f"doc_{i}"])
    tagged_docs.append(tagged_doc)

print("Размеченные документы:")
for doc in tagged_docs[:3]:
    print(f"  Слова: {doc.words}")
    print(f"  Тег: {doc.tags}")
# Out:
# Размеченные документы:
#   Слова: ['machine', 'learning', 'is', 'interesting']
#   Тег: ['doc_0']
#   Слова: ['deep', 'learning', 'uses', 'neural', 'networks']
#   Тег: ['doc_1']
#   Слова: ['python', 'programming', 'for', 'data', 'science']
#   Тег: ['doc_2']

# %%
# Обучаем Doc2Vec
doc_model = Doc2Vec(
    documents=tagged_docs,
    vector_size=50,
    window=3,
    min_count=1,
    workers=2,
    epochs=20
)

print("Doc2Vec модель обучена!")
print(f"Количество документов: {len(doc_model.dv.key_to_index)}")
# Out:
# Doc2Vec модель обучена!
# Количество документов: 5

# %%
# Получаем вектор документа
doc_vector = doc_model.dv["doc_0"]
print(f"Вектор документа doc_0: {doc_vector[:5]}...")

# Находим похожие документы
similar_docs = doc_model.dv.most_similar("doc_0", topn=2)
print("\nДокументы, похожие на doc_0:")
for doc_tag, similarity in similar_docs:
    doc_id = int(doc_tag.split('_')[1])
    print(f"  {doc_tag}: {similarity:.4f}")
    print(f"    Текст: {documents[doc_id]}")
# Out:
# Вектор документа doc_0: [-0.01057    -0.01198188 -0.01982618  0.01710627  0.00710373]...
#
# Документы, похожие на doc_0:
#   doc_1: 0.2735
#     Текст: deep learning uses neural networks
#   doc_2: 0.1275
#     Текст: python programming for data science

# %%
# Сравниваем схожесть документов
def compare_documents(doc1_id, doc2_id):
    similarity = doc_model.dv.similarity(f"doc_{doc1_id}", f"doc_{doc2_id}")
    print(f"Схожесть doc_{doc1_id} и doc_{doc2_id}: {similarity:.4f}")
    print(f"  doc_{doc1_id}: {documents[doc1_id]}")
    print(f"  doc_{doc2_id}: {documents[doc2_id]}")

compare_documents(0, 1)  # machine learning vs deep learning
compare_documents(0, 3)  # machine learning vs AI
# Out:
# Схожесть doc_0 и doc_1: 0.2735
#   doc_0: machine learning is interesting
#   doc_1: deep learning uses neural networks
# Схожесть doc_0 и doc_3: -0.0822
#   doc_0: machine learning is interesting
#   doc_3: artificial intelligence is amazing

# %% [markdown]
# 8. Сравните схожесть doc_2 и doc_4

# %%
compare_documents(2, 4)
# Out:
# Схожесть doc_2 и doc_4: -0.0362
#   doc_2: python programming for data science
#   doc_4: computer vision processes images

# %% [markdown]
# 9. Найдите самый похожий документ на doc_1

# %%
similar_to_doc1 = doc_model.dv.most_similar("doc_1", topn=1)

print("Самый похожий документ на doc_1:")
for doc_tag, similarity in similar_to_doc1:
    doc_id = int(doc_tag.split('_')[1])
    print(f"  Тег: {doc_tag} (Коэффициент сходства: {similarity:.4f})")
    print(f"  Текст: '{documents[doc_id]}'")
# Out:
# Самый похожий документ на doc_1:
#   Тег: doc_0 (Коэффициент сходства: 0.2735)
#   Текст: 'machine learning is interesting'

# %% [markdown]
# 10. Выберите любую из трёх моделей. Обучите модели с разной размерностью (10, 50, 100). Продемонстрируйте качество их работы на примере поиска похожих слов (выберите любые 3 примера, соответствующих тематике корпуса из пункта 4)

# %%
dimensions = [10, 50, 100]
trained_models = {}


for i in dimensions:
    trained_models[i] = Word2Vec(
        sentences=cooking_sentences,
        vector_size=dim,
        window=3,
        min_count=1,
        workers=2,
        sg=1,
        seed=42
    )


test_words = ['варить', 'овощи', 'мясо']

# 3. Демонстрируем и сравниваем результаты для каждой размерности
for i in dimensions:
    print(f"\n{'='*15} РЕЗУЛЬТАТЫ ДЛЯ РАЗМЕРНОСТИ ВЕКТОРА: {i} {'='*15}")
    for word in test_words:
        print(f"Топ-3 похожих слова для '{word}':")
        try:
            # Находим топ-3 похожих слова в пространстве текущей модели
            similar = trained_models[i].wv.most_similar(word, topn=3)
            for sim_word, score in similar:
                print(f"  {sim_word}: {score:.4f}")
        except KeyError:
            print(f"  Слово '{word}' отсутствует в словаре модели.")
# Out:
# =============== РЕЗУЛЬТАТЫ ДЛЯ РАЗМЕРНОСТИ ВЕКТОРА: 10 ===============
# Топ-3 похожих слова для 'варить':
#   хлеб: 0.8292
#   дрожжи: 0.6746
#   духовка: 0.6099
# Топ-3 похожих слова для 'овощи':
#   бекон: 0.7301
#   парить: 0.7164
#   горшок: 0.4803
# Топ-3 похожих слова для 'мясо':
#   яйца: 0.6516
#   тушить: 0.5785
#   суп: 0.5544
#
# =============== РЕЗУЛЬТАТЫ ДЛЯ РАЗМЕРНОСТИ ВЕКТОРА: 50 ===============
# Топ-3 похожих слова для 'варить':
#   горшок: 0.2121
#   резать: 0.2099
#   салат: 0.2008
# Топ-3 похожих слова для 'овощи':
#   вино: 0.3312
#   сковорода: 0.2633
#   взбивать: 0.2424
# Топ-3 похожих слова для 'мясо':
#   торт: 0.3314
#   огурцы: 0.2515
#   мариновать: 0.2489
#
# =============== РЕЗУЛЬТАТЫ ДЛЯ РАЗМЕРНОСТИ ВЕКТОРА: 100 ===============
# Топ-3 похожих слова для 'варить':
#   резать: 0.2663
#   здоровое: 0.1861
#   специи: 0.1613
# Топ-3 похожих слова для 'овощи':
#   холодильник: 0.2155
#   курица: 0.2019
#   брокколи: 0.1933
# Топ-3 похожих слова для 'мясо':
#   холодильник: 0.2049
#   горшок: 0.1908
#   яйца: 0.1806
